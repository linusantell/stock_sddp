# %%
using SDDP, GLPK, JuMP, Pipe, DataFrames, CSV

# %%
STAGES = 20

stock_projections = reduce(vcat, [vec(0.98:0.01:1.02).^(i/2) for i in 1:STAGES]')
N1, N2 = size(stock_projections)
probabilities = zeros(size(stock_projections))
for n1 in 1:N1, n2 in 1:N2
    probabilities[n1, n2] = 1/N2
end

# %%
stock_projections
# Out:
# 20×5 Matrix{Float64}:
#  0.989949  0.994987  1.0  1.00499  1.00995
#  0.98      0.99      1.0  1.01     1.02
#  0.970151  0.985038  1.0  1.01504  1.03015
#  0.9604    0.9801    1.0  1.0201   1.0404
#  0.950747  0.975187  1.0  1.02519  1.05075
#  0.941192  0.970299  1.0  1.0303   1.06121
#  0.931733  0.965435  1.0  1.03544  1.07177
#  0.922368  0.960596  1.0  1.0406   1.08243
#  0.913098  0.955781  1.0  1.04579  1.0932
#  0.903921  0.95099   1.0  1.05101  1.10408
#  0.894836  0.946223  1.0  1.05625  1.11507
#  0.885842  0.94148   1.0  1.06152  1.12616
#  0.876939  0.936761  1.0  1.06681  1.13737
#  0.868126  0.932065  1.0  1.07214  1.14869
#  0.8594    0.927393  1.0  1.07748  1.16012
#  0.850763  0.922745  1.0  1.08286  1.17166
#  0.842212  0.918119  1.0  1.08826  1.18332
#  0.833748  0.913517  1.0  1.09369  1.19509
#  0.825368  0.908938  1.0  1.09914  1.20698
#  0.817073  0.904382  1.0  1.10462  1.21899

# %%
model = SDDP.LinearPolicyGraph(
    stages = STAGES,
    sense = :Max,
    upper_bound = STAGES*1250,
    optimizer = GLPK.Optimizer,
) do subproblem, node

    M = 10000
    c = 1.01
    p = 0.99
    discount = 1/(1.02^node)
    
    stock_val_dist = stock_projections[node, :]
    stock_pr_dist = probabilities[node, :]
    
    
    
    
    @variable(
        subproblem,
        invest >= 0
    )
    
    @variable(
        subproblem,
        sell >= 0
    )
    
    @variable(
        subproblem,
        buy_order,
        Bin,
        SDDP.State,
        initial_value = 0
    )
    
    @variable(
        subproblem,
        sell_order,
        Bin,
        SDDP.State,
        initial_value = 0
    )
    
    @variable(
        subproblem,
        stock_owned,
        SDDP.State,
        initial_value = 0
    )
    
    @variable(
        subproblem,
        cash,
        SDDP.State,
        initial_value = 1000
    )
    
    @variable(
        subproblem,
        wealth,
        SDDP.State,
        initial_value = 0
    )
    
    @constraint(
        subproblem,
        invest_limit,
        invest <= cash.in
    )
    
    @constraint(
        subproblem,
        buy_order_update,
        invest <= M * buy_order.in
    )
    
    @constraint(
        subproblem,
        buy_order_forced,
        invest >= cash.in - M * (1 - buy_order.in)
    )
    
    @constraint(
        subproblem,
        sell_limit,
        sell <= stock_owned.in 
    )
    
    @constraint(
        subproblem,
        stock_profit_limit,
        sell <= M * sell_order.in
    )
    
    @constraint(
        subproblem,
        update_stock_owned,
        1.0 * stock_owned.out == stock_owned.in + invest/c - sell
    )


    @variable(
        subproblem,
        stock_return
    )
    
    @variable(
        subproblem,
        stock_return_cumulative,
        SDDP.State,
        initial_value = 1
    )
    
    @constraint(
        subproblem,
        update_returns,
        -stock_return_cumulative.out + 1.0 * stock_return_cumulative.in == 0
    )
    
    SDDP.parameterize(subproblem, stock_val_dist, stock_pr_dist) do ω
    
        JuMP.set_normalized_coefficient(
            update_stock_owned,
            subproblem[:stock_owned].out,
            1/ω
        )
        
        JuMP.set_normalized_coefficient(
            update_returns,
            subproblem[:stock_return_cumulative].in,
            ω
        )
        
        JuMP.fix(stock_return, ω)

    end
    
    
    @constraint(
        subproblem,
        update_cash,
        cash.out == cash.in - invest + p * sell
    )
    
    if node == STAGES-1
       @constraint(
            subproblem,
            buy_order.out == 0
            ) 
        
    end
    
    @constraint(
        subproblem,
        update_wealth,
        wealth.out == discount * cash.out + stock_owned.out
    )
    
    @constraint(
        subproblem,
        buy_or_sell,
        buy_order.out+sell_order.out <= 1
    )
    
    @stageobjective(
        subproblem, 
        wealth.in
    )

end
# Out:
# A policy graph with 20 nodes.
#  Node indices: 1, ..., 20

# %%
SDDP.train(model; iteration_limit = 100, risk_measure = SDDP.EAVaR(beta = 0.25, lambda = 0.3))
# Out:
# ------------------------------------------------------------------------------
#                       SDDP.jl (c) Oscar Dowson, 2017-21
#
# Problem
#   Nodes           : 20
#   State variables : 6
#   Scenarios       : 9.53674e+13
#   Existing cuts   : false
#   Subproblem structure                      : (min, max)
#     Variables                               : (16, 16)
#     VariableRef in MOI.LessThan{Float64}    : (1, 1)
#     VariableRef in MOI.ZeroOne              : (2, 2)
#     AffExpr in MOI.LessThan{Float64}        : (5, 5)
#     AffExpr in MOI.GreaterThan{Float64}     : (1, 1)
#     AffExpr in MOI.EqualTo{Float64}         : (4, 5)
#     VariableRef in MOI.GreaterThan{Float64} : (2, 3)
# Options
#   Solver          : serial mode
#   Risk measure    : A convex combination of 0.3 * SDDP.Expectation() + 0.7 * SDDP.AVaR(0.25)
#   Sampling scheme : SDDP.InSampleMonteCarlo
#
# Numerical stability report
#   Non-zero Matrix range     [7e-01, 1e+04]
#   Non-zero Objective range  [1e+00, 1e+00]
#   Non-zero Bounds range     [2e+04, 2e+04]
#   Non-zero RHS range        [1e+00, 1e+04]
# No problems detected
#
#  Iteration    Simulation       Bound         Time (s)    Proc. ID   # Solves
#         1    1.567846e+04   2.500000e+04   1.600003e-02          1        120
#         2    1.939140e+04   2.500000e+04   2.399993e-02          1        240
#         3    1.553658e+04   2.500000e+04   3.400016e-02          1        360
#         4    1.789744e+04   2.500000e+04   6.200004e-02          1        480
#         5    1.656397e+04   2.500000e+04   7.700014e-02          1        600
#         6    1.860419e+04   2.500000e+04   9.299994e-02          1        720
#         7    1.782627e+04   2.500000e+04   9.299994e-02          1        840
#         8    2.075362e+04   2.500000e+04   1.130002e-01          1        960
#         9    1.928139e+04   2.500000e+04   1.230001e-01          1       1080
#        10    1.698772e+04   2.165197e+04   1.320000e-01          1       1200
#        11    2.475509e+04   2.158400e+04   1.400001e-01          1       1320
#        12    1.777361e+04   2.123116e+04   1.500001e-01          1       1440
#        13    1.752824e+04   2.123116e+04   1.600001e-01          1       1560
#        14    1.761070e+04   2.123116e+04   1.619999e-01          1       1680
#        15    1.771449e+04   2.123116e+04   1.770000e-01          1       1800
#        16    1.538338e+04   2.123116e+04   1.770000e-01          1       1920
#        17    1.706142e+04   2.123116e+04   1.930001e-01          1       2040
#        18    1.607464e+04   2.123116e+04   2.090001e-01          1       2160
#        19    1.662379e+04   2.123116e+04   2.210000e-01          1       2280
#        20    1.623067e+04   2.123116e+04   2.300000e-01          1       2400
#        21    1.607933e+04   2.123116e+04   2.300000e-01          1       2520
#        22    1.717924e+04   2.123116e+04   2.530000e-01          1       2640
#        23    1.637675e+04   2.123116e+04   2.650001e-01          1       2760
#        24    1.665949e+04   2.123116e+04   2.760000e-01          1       2880
#        25    1.586573e+04   2.123116e+04   2.880001e-01          1       3000
#        26    1.690514e+04   2.123116e+04   2.960000e-01          1       3120
#        27    1.573875e+04   2.123116e+04   2.960000e-01          1       3240
#        28    1.690474e+04   2.123116e+04   3.220000e-01          1       3360
#        29    1.665949e+04   2.123116e+04   3.350000e-01          1       3480
#        30    1.621880e+04   2.123116e+04   3.480000e-01          1       3600
#        31    1.607631e+04   2.123116e+04   3.600001e-01          1       3720
#        32    1.601062e+04   2.123116e+04   3.620000e-01          1       3840
#        33    1.631945e+04   2.123116e+04   3.770001e-01          1       3960
#        34    1.645785e+04   2.123116e+04   3.930001e-01          1       4080
#        35    1.757726e+04   2.123116e+04   4.080000e-01          1       4200
#        36    1.653237e+04   2.123116e+04   4.240000e-01          1       4320
#        37    1.623557e+04   2.123116e+04   4.290001e-01          1       4440
#        38    1.662379e+04   2.123116e+04   4.520001e-01          1       4560
#        39    1.681016e+04   2.123116e+04   4.660001e-01          1       4680
#        40    1.742215e+04   2.123116e+04   4.790001e-01          1       4800
#        41    1.719536e+04   2.123116e+04   4.790001e-01          1       4920
#        42    1.607464e+04   2.123116e+04   4.950001e-01          1       5040
#        43    1.616200e+04   2.123116e+04   5.100000e-01          1       5160
#        44    1.783947e+04   2.123116e+04   5.369999e-01          1       5280
#        45    1.730514e+04   2.123116e+04   5.530000e-01          1       5400
#        46    1.645190e+04   2.123116e+04   5.690000e-01          1       5520
#        47    1.680626e+04   2.123116e+04   5.790000e-01          1       5640
#        48    1.701205e+04   2.123116e+04   5.950000e-01          1       5760
#        49    1.629439e+04   2.123116e+04   6.100001e-01          1       5880
#        50    1.631945e+04   2.123116e+04   6.259999e-01          1       6000
#        51    1.649295e+04   2.123116e+04   6.480000e-01          1       6120
#        52    1.621880e+04   2.123116e+04   6.650000e-01          1       6240
#        53    1.646977e+04   2.123116e+04   6.820002e-01          1       6360
#        54    1.616200e+04   2.123116e+04   6.960001e-01          1       6480
#        55    1.640470e+04   2.123116e+04   7.120001e-01          1       6600
#        56    1.673352e+04   2.123116e+04   7.270000e-01          1       6720
#        57    1.653416e+04   2.123116e+04   7.869999e-01          1       6840
#        58    1.661400e+04   2.123116e+04   8.050001e-01          1       6960
#        59    1.688435e+04   2.123116e+04   8.230000e-01          1       7080
#        60    1.698583e+04   2.123116e+04   8.440001e-01          1       7200
#        61    1.701205e+04   2.123116e+04   8.630002e-01          1       7320
#        62    1.700570e+04   2.123116e+04   8.830001e-01          1       7440
#        63    1.663783e+04   2.123116e+04   9.030001e-01          1       7560
#        64    1.629501e+04   2.123116e+04   9.210000e-01          1       7680
#        65    1.593510e+04   2.123116e+04   9.300001e-01          1       7800
#        66    1.688435e+04   2.123116e+04   9.460001e-01          1       7920
#        67    1.639492e+04   2.123116e+04   9.640000e-01          1       8040
#        68    1.682752e+04   2.123116e+04   9.980001e-01          1       8160
#        69    1.672769e+04   2.123116e+04   1.018000e+00          1       8280
#        70    1.639492e+04   2.123116e+04   1.028000e+00          1       8400
#        71    1.656397e+04   2.123116e+04   1.044000e+00          1       8520
#        72    1.670295e+04   2.123116e+04   1.080000e+00          1       8640
#        73    1.701205e+04   2.123116e+04   1.103000e+00          1       8760
#        74    1.607464e+04   2.123116e+04   1.124000e+00          1       8880
#        75    1.637008e+04   2.123116e+04   1.144000e+00          1       9000
#        76    1.580206e+04   2.123116e+04   1.160000e+00          1       9120
#        77    1.688987e+04   2.123116e+04   1.192000e+00          1       9240
#        78    1.645189e+04   2.123116e+04   1.216000e+00          1       9360
#        79    1.690474e+04   2.123116e+04   1.228000e+00          1       9480
#        80    1.709252e+04   2.123116e+04   1.291000e+00          1       9600
#        81    1.630480e+04   2.123116e+04   1.320000e+00          1       9720
#        82    1.629501e+04   2.123116e+04   1.343000e+00          1       9840
#        83    1.639492e+04   2.123116e+04   1.362000e+00          1       9960
#        84    1.743907e+04   2.123116e+04   1.377000e+00          1      10080
#        85    1.733502e+04   2.123116e+04   1.409000e+00          1      10200
#        86    1.672769e+04   2.123116e+04   1.436000e+00          1      10320
#        87    1.675294e+04   2.123116e+04   1.462000e+00          1      10440
#        88    1.614757e+04   2.123116e+04   1.478000e+00          1      10560
#        89    1.757726e+04   2.123116e+04   1.494000e+00          1      10680
#        90    1.637675e+04   2.123116e+04   1.525000e+00          1      10800
#        91    1.642434e+04   2.123116e+04   1.561000e+00          1      10920
#        92    1.743907e+04   2.123116e+04   1.586000e+00          1      11040
#        93    1.621879e+04   2.123116e+04   1.611000e+00          1      11160
#        94    1.688792e+04   2.123116e+04   1.626000e+00          1      11280
#        95    1.730514e+04   2.123116e+04   1.671000e+00          1      11400
#        96    1.637008e+04   2.123116e+04   1.700000e+00          1      11520
#        97    1.629439e+04   2.123116e+04   1.743000e+00          1      11640
#        98    1.621879e+04   2.123116e+04   1.781000e+00          1      11760
#        99    1.695766e+04   2.123116e+04   1.807000e+00          1      11880
#       100    1.735824e+04   2.123116e+04   1.829000e+00          1      12000
#
# Terminating training
#   Status         : iteration_limit
#   Total time (s) : 1.829000e+00
#   Total solves   : 12000
#   Best bound     :  2.123116e+04
#   Simulation CI  :  1.685696e+04 ± 2.199491e+02
# ------------------------------------------------------------------------------

# %%
mylist = [
    :wealth,
    :invest,
    :buy_order,
    :sell_order,
    :sell,
    :stock_owned,
    :cash,
    :stock_return,
    :stock_return_cumulative
]

REPLICATIONS = 100

historical = false
if historical
    simulations = SDDP.simulate(
        model,
        sampling_scheme = SDDP.Historical(
            [(1, 1-6/100), (2, 1 - 2.8/100), (3, 1 + 6/100), (4, 1 - 4.6/100)]
        ),
        REPLICATIONS,
        mylist
    )
else
    simulations = SDDP.simulate(
            model,
            REPLICATIONS,
            mylist
        )
end

show = true
if show
    for j in 1:4, i in 1:STAGES
        println("replication:",j, ", stage:", i)
        for item in mylist
            print(string(item)*"("*string(i)*")=")
            print(simulations[j][i][item])
            print("\n")
        end
        print("\n ----------")
        print("\n ----------\n")
    end
end
# Out:
# replication:1, stage:1
# wealth(1)=SDDP.State{Float64}(0.0, 980.3921568627451)
# invest(1)=0.0
# buy_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell(1)=0.0
# stock_owned(1)=SDDP.State{Float64}(0.0, 0.0)
# cash(1)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(1)=1.0099504938362078
# stock_return_cumulative(1)=SDDP.State{Float64}(1.0, 1.0099504938362078)
#
#  ----------
#  ----------
# replication:1, stage:2
# wealth(2)=SDDP.State{Float64}(980.3921568627451, 961.1687812379854)
# invest(2)=0.0
# buy_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell(2)=0.0
# stock_owned(2)=SDDP.State{Float64}(0.0, 0.0)
# cash(2)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(2)=0.99
# stock_return_cumulative(2)=SDDP.State{Float64}(1.0099504938362078, 0.9998509888978457)
#
#  ----------
#  ----------
# replication:1, stage:3
# wealth(3)=SDDP.State{Float64}(961.1687812379854, 942.3223345470446)
# invest(3)=0.0
# buy_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell(3)=0.0
# stock_owned(3)=SDDP.State{Float64}(0.0, 0.0)
# cash(3)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(3)=0.9701505037879432
# stock_return_cumulative(3)=SDDP.State{Float64}(0.9998509888978457, 0.9700059405921183)
#
#  ----------
#  ----------
# replication:1, stage:4
# wealth(4)=SDDP.State{Float64}(942.3223345470446, 923.8454260265142)
# invest(4)=0.0
# buy_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell(4)=0.0
# stock_owned(4)=SDDP.State{Float64}(0.0, 0.0)
# cash(4)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(4)=1.0201
# stock_return_cumulative(4)=SDDP.State{Float64}(0.9700059405921183, 0.9895030599980199)
#
#  ----------
#  ----------
# replication:1, stage:5
# wealth(5)=SDDP.State{Float64}(923.8454260265142, 905.730809829916)
# invest(5)=0.0
# buy_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell(5)=0.0
# stock_owned(5)=SDDP.State{Float64}(0.0, 0.0)
# cash(5)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(5)=1.025187812110542
# stock_return_cumulative(5)=SDDP.State{Float64}(0.9895030599980199, 1.0144264771560565)
#
#  ----------
#  ----------
# replication:1, stage:6
# wealth(6)=SDDP.State{Float64}(905.730809829916, 887.9713821861919)
# invest(6)=0.0
# buy_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell(6)=0.0
# stock_owned(6)=SDDP.State{Float64}(0.0, 0.0)
# cash(6)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(6)=1.0612080000000002
# stock_return_cumulative(6)=SDDP.State{Float64}(1.0144264771560565, 1.0765174929698245)
#
#  ----------
#  ----------
# replication:1, stage:7
# wealth(7)=SDDP.State{Float64}(887.9713821861919, 870.5601786139138)
# invest(7)=0.0
# buy_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell(7)=0.0
# stock_owned(7)=SDDP.State{Float64}(0.0, 0.0)
# cash(7)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(7)=0.9317325438379406
# stock_return_cumulative(7)=SDDP.State{Float64}(1.0765174929698245, 1.0030263822108167)
#
#  ----------
#  ----------
# replication:1, stage:8
# wealth(8)=SDDP.State{Float64}(870.5601786139138, 853.4903711901114)
# invest(8)=0.0
# buy_order(8)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(8)=SDDP.State{Float64}(0.0, 1.0)
# sell(8)=0.0
# stock_owned(8)=SDDP.State{Float64}(0.0, 0.0)
# cash(8)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(8)=0.9223681599999999
# stock_return_cumulative(8)=SDDP.State{Float64}(1.0030263822108167, 0.9251595985912476)
#
#  ----------
#  ----------
# replication:1, stage:9
# wealth(9)=SDDP.State{Float64}(853.4903711901114, 836.7552658726582)
# invest(9)=0.0
# buy_order(9)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(9)=SDDP.State{Float64}(1.0, 1.0)
# sell(9)=0.0
# stock_owned(9)=SDDP.State{Float64}(0.0, 0.0)
# cash(9)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(9)=0.9130978929611817
# stock_return_cumulative(9)=SDDP.State{Float64}(0.9251595985912476, 0.8447612801264809)
#
#  ----------
#  ----------
# replication:1, stage:10
# wealth(10)=SDDP.State{Float64}(836.7552658726582, 820.3482998751551)
# invest(10)=0.0
# buy_order(10)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(10)=SDDP.State{Float64}(1.0, 1.0)
# sell(10)=0.0
# stock_owned(10)=SDDP.State{Float64}(0.0, 0.0)
# cash(10)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(10)=1.0510100501000001
# stock_return_cumulative(10)=SDDP.State{Float64}(0.8447612801264809, 0.887852595348273)
#
#  ----------
#  ----------
# replication:1, stage:11
# wealth(11)=SDDP.State{Float64}(820.3482998751551, 804.2630390932893)
# invest(11)=0.0
# buy_order(11)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(11)=SDDP.State{Float64}(1.0, 1.0)
# sell(11)=0.0
# stock_owned(11)=SDDP.State{Float64}(0.0, 0.0)
# cash(11)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(11)=0.9462231524638975
# stock_return_cumulative(11)=SDDP.State{Float64}(0.887852595348273, 0.8401066816936961)
#
#  ----------
#  ----------
# replication:1, stage:12
# wealth(12)=SDDP.State{Float64}(804.2630390932893, 788.4931755816565)
# invest(12)=-3.2954698008896196e-13
# buy_order(12)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(12)=SDDP.State{Float64}(1.0, 1.0)
# sell(12)=0.0
# stock_owned(12)=SDDP.State{Float64}(0.0, 0.0)
# cash(12)=SDDP.State{Float64}(1000.0, 1000.0000000000003)
# stock_return(12)=1.126162419264
# stock_return_cumulative(12)=SDDP.State{Float64}(0.8401066816936961, 0.946096573096024)
#
#  ----------
#  ----------
# replication:1, stage:13
# wealth(13)=SDDP.State{Float64}(788.4931755816565, 773.0325250800553)
# invest(13)=0.0
# buy_order(13)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(13)=SDDP.State{Float64}(1.0, 1.0)
# sell(13)=0.0
# stock_owned(13)=SDDP.State{Float64}(0.0, 0.0)
# cash(13)=SDDP.State{Float64}(1000.0000000000003, 1000.0000000000003)
# stock_return(13)=1.0668145482853566
# stock_return_cumulative(13)=SDDP.State{Float64}(0.946096573096024, 1.0093095882617587)
#
#  ----------
#  ----------
# replication:1, stage:14
# wealth(14)=SDDP.State{Float64}(773.0325250800553, 757.8750245882896)
# invest(14)=0.0
# buy_order(14)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(14)=SDDP.State{Float64}(1.0, 1.0)
# sell(14)=0.0
# stock_owned(14)=SDDP.State{Float64}(0.0, 0.0)
# cash(14)=SDDP.State{Float64}(1000.0000000000003, 1000.0000000000003)
# stock_return(14)=0.8681255332467199
# stock_return_cumulative(14)=SDDP.State{Float64}(1.0093095882617587, 0.8762074245207666)
#
#  ----------
#  ----------
# replication:1, stage:15
# wealth(15)=SDDP.State{Float64}(757.8750245882896, 743.0147299885192)
# invest(15)=0.0
# buy_order(15)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(15)=SDDP.State{Float64}(1.0, 1.0)
# sell(15)=0.0
# stock_owned(15)=SDDP.State{Float64}(0.0, 0.0)
# cash(15)=SDDP.State{Float64}(1000.0000000000003, 1000.0000000000003)
# stock_return(15)=0.8594004320719205
# stock_return_cumulative(15)=SDDP.State{Float64}(0.8762074245207666, 0.7530130392177715)
#
#  ----------
#  ----------
# replication:1, stage:16
# wealth(16)=SDDP.State{Float64}(743.0147299885192, 728.4458137142344)
# invest(16)=0.0
# buy_order(16)=SDDP.State{Float64}(0.0, 1.0)
# sell_order(16)=SDDP.State{Float64}(1.0, 0.0)
# sell(16)=0.0
# stock_owned(16)=SDDP.State{Float64}(0.0, 0.0)
# cash(16)=SDDP.State{Float64}(1000.0000000000003, 1000.0000000000003)
# stock_return(16)=0.9227446944279201
# stock_return_cumulative(16)=SDDP.State{Float64}(0.7530130392177715, 0.694838786773242)
#
#  ----------
#  ----------
# replication:1, stage:17
# wealth(17)=SDDP.State{Float64}(728.4458137142344, 909.0290877352154)
# invest(17)=1000.0000000000003
# buy_order(17)=SDDP.State{Float64}(1.0, 0.0)
# sell_order(17)=SDDP.State{Float64}(0.0, 0.0)
# sell(17)=0.0
# stock_owned(17)=SDDP.State{Float64}(0.0, 909.0290877352154)
# cash(17)=SDDP.State{Float64}(1000.0000000000003, 0.0)
# stock_return(17)=0.9181193786125673
# stock_return_cumulative(17)=SDDP.State{Float64}(0.694838786773242, 0.6379449551481591)
#
#  ----------
#  ----------
# replication:1, stage:18
# wealth(18)=SDDP.State{Float64}(909.0290877352154, 757.9009676104474)
# invest(18)=0.0
# buy_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell(18)=0.0
# stock_owned(18)=SDDP.State{Float64}(909.0290877352154, 757.9009676104474)
# cash(18)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(18)=0.8337477621301498
# stock_return_cumulative(18)=SDDP.State{Float64}(0.6379449551481591, 0.5318851787169964)
#
#  ----------
#  ----------
# replication:1, stage:19
# wealth(19)=SDDP.State{Float64}(757.9009676104474, 757.9009676104474)
# invest(19)=0.0
# buy_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell(19)=0.0
# stock_owned(19)=SDDP.State{Float64}(757.9009676104474, 757.9009676104474)
# cash(19)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(19)=1.0
# stock_return_cumulative(19)=SDDP.State{Float64}(0.5318851787169964, 0.5318851787169964)
#
#  ----------
#  ----------
# replication:1, stage:20
# wealth(20)=SDDP.State{Float64}(757.9009676104474, 923.8770504257627)
# invest(20)=0.0
# buy_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell(20)=0.0
# stock_owned(20)=SDDP.State{Float64}(757.9009676104474, 923.8770504257627)
# cash(20)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(20)=1.2189944199947573
# stock_return_cumulative(20)=SDDP.State{Float64}(0.5318851787169964, 0.6483650649339329)
#
#  ----------
#  ----------
# replication:2, stage:1
# wealth(1)=SDDP.State{Float64}(0.0, 980.3921568627451)
# invest(1)=0.0
# buy_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell(1)=0.0
# stock_owned(1)=SDDP.State{Float64}(0.0, 0.0)
# cash(1)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(1)=0.9899494936611666
# stock_return_cumulative(1)=SDDP.State{Float64}(1.0, 0.9899494936611666)
#
#  ----------
#  ----------
# replication:2, stage:2
# wealth(2)=SDDP.State{Float64}(980.3921568627451, 961.1687812379854)
# invest(2)=0.0
# buy_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(2)=SDDP.State{Float64}(0.0, 1.0)
# sell(2)=0.0
# stock_owned(2)=SDDP.State{Float64}(0.0, 0.0)
# cash(2)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(2)=1.01
# stock_return_cumulative(2)=SDDP.State{Float64}(0.9899494936611666, 0.9998489885977783)
#
#  ----------
#  ----------
# replication:2, stage:3
# wealth(3)=SDDP.State{Float64}(961.1687812379854, 942.3223345470446)
# invest(3)=0.0
# buy_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(3)=SDDP.State{Float64}(1.0, 0.0)
# sell(3)=0.0
# stock_owned(3)=SDDP.State{Float64}(0.0, 0.0)
# cash(3)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(3)=0.9850375627355538
# stock_return_cumulative(3)=SDDP.State{Float64}(0.9998489885977783, 0.984888810831964)
#
#  ----------
#  ----------
# replication:2, stage:4
# wealth(4)=SDDP.State{Float64}(942.3223345470446, 923.8454260265142)
# invest(4)=0.0
# buy_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell(4)=0.0
# stock_owned(4)=SDDP.State{Float64}(0.0, 0.0)
# cash(4)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(4)=0.9603999999999999
# stock_return_cumulative(4)=SDDP.State{Float64}(0.984888810831964, 0.9458872139230181)
#
#  ----------
#  ----------
# replication:2, stage:5
# wealth(5)=SDDP.State{Float64}(923.8454260265142, 905.730809829916)
# invest(5)=0.0
# buy_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell(5)=0.0
# stock_owned(5)=SDDP.State{Float64}(0.0, 0.0)
# cash(5)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(5)=1.0507524937871906
# stock_return_cumulative(5)=SDDP.State{Float64}(0.9458872139230181, 0.9938933488710291)
#
#  ----------
#  ----------
# replication:2, stage:6
# wealth(6)=SDDP.State{Float64}(905.730809829916, 887.9713821861919)
# invest(6)=0.0
# buy_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell(6)=0.0
# stock_owned(6)=SDDP.State{Float64}(0.0, 0.0)
# cash(6)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(6)=1.0612080000000002
# stock_return_cumulative(6)=SDDP.State{Float64}(0.9938933488710291, 1.054727572968727)
#
#  ----------
#  ----------
# replication:2, stage:7
# wealth(7)=SDDP.State{Float64}(887.9713821861919, 870.5601786139138)
# invest(7)=0.0
# buy_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell(7)=0.0
# stock_owned(7)=SDDP.State{Float64}(0.0, 0.0)
# cash(7)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(7)=1.0
# stock_return_cumulative(7)=SDDP.State{Float64}(1.054727572968727, 1.054727572968727)
#
#  ----------
#  ----------
# replication:2, stage:8
# wealth(8)=SDDP.State{Float64}(870.5601786139138, 853.4903711901114)
# invest(8)=0.0
# buy_order(8)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(8)=SDDP.State{Float64}(0.0, 1.0)
# sell(8)=0.0
# stock_owned(8)=SDDP.State{Float64}(0.0, 0.0)
# cash(8)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(8)=0.9223681599999999
# stock_return_cumulative(8)=SDDP.State{Float64}(1.054727572968727, 0.9728471307804304)
#
#  ----------
#  ----------
# replication:2, stage:9
# wealth(9)=SDDP.State{Float64}(853.4903711901114, 836.7552658726582)
# invest(9)=0.0
# buy_order(9)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(9)=SDDP.State{Float64}(1.0, 1.0)
# sell(9)=0.0
# stock_owned(9)=SDDP.State{Float64}(0.0, 0.0)
# cash(9)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(9)=1.0932028945361931
# stock_return_cumulative(9)=SDDP.State{Float64}(0.9728471307804304, 1.063519299310397)
#
#  ----------
#  ----------
# replication:2, stage:10
# wealth(10)=SDDP.State{Float64}(836.7552658726582, 820.3482998751551)
# invest(10)=0.0
# buy_order(10)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(10)=SDDP.State{Float64}(1.0, 1.0)
# sell(10)=0.0
# stock_owned(10)=SDDP.State{Float64}(0.0, 0.0)
# cash(10)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(10)=0.9509900498999999
# stock_return_cumulative(10)=SDDP.State{Float64}(1.063519299310397, 1.0113962715208074)
#
#  ----------
#  ----------
# replication:2, stage:11
# wealth(11)=SDDP.State{Float64}(820.3482998751551, 804.2630390932893)
# invest(11)=0.0
# buy_order(11)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(11)=SDDP.State{Float64}(1.0, 1.0)
# sell(11)=0.0
# stock_owned(11)=SDDP.State{Float64}(0.0, 0.0)
# cash(11)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(11)=0.9462231524638975
# stock_return_cumulative(11)=SDDP.State{Float64}(1.0113962715208074, 0.9570065684286504)
#
#  ----------
#  ----------
# replication:2, stage:12
# wealth(12)=SDDP.State{Float64}(804.2630390932893, 788.4931755816563)
# invest(12)=0.0
# buy_order(12)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(12)=SDDP.State{Float64}(1.0, 1.0)
# sell(12)=0.0
# stock_owned(12)=SDDP.State{Float64}(0.0, 0.0)
# cash(12)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(12)=1.0615201506010001
# stock_return_cumulative(12)=SDDP.State{Float64}(0.9570065684286504, 1.0158817566445273)
#
#  ----------
#  ----------
# replication:2, stage:13
# wealth(13)=SDDP.State{Float64}(788.4931755816563, 773.032525080055)
# invest(13)=0.0
# buy_order(13)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(13)=SDDP.State{Float64}(1.0, 1.0)
# sell(13)=0.0
# stock_owned(13)=SDDP.State{Float64}(0.0, 0.0)
# cash(13)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(13)=1.0668145482853566
# stock_return_cumulative(13)=SDDP.State{Float64}(1.0158817566445273, 1.0837574373260659)
#
#  ----------
#  ----------
# replication:2, stage:14
# wealth(14)=SDDP.State{Float64}(773.032525080055, 757.8750245882894)
# invest(14)=0.0
# buy_order(14)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(14)=SDDP.State{Float64}(1.0, 1.0)
# sell(14)=0.0
# stock_owned(14)=SDDP.State{Float64}(0.0, 0.0)
# cash(14)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(14)=0.9320653479069899
# stock_return_cumulative(14)=SDDP.State{Float64}(1.0837574373260659, 1.0101327528681074)
#
#  ----------
#  ----------
# replication:2, stage:15
# wealth(15)=SDDP.State{Float64}(757.8750245882894, 743.0147299885189)
# invest(15)=0.0
# buy_order(15)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(15)=SDDP.State{Float64}(1.0, 1.0)
# sell(15)=0.0
# stock_owned(15)=SDDP.State{Float64}(0.0, 0.0)
# cash(15)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(15)=1.1601156573049645
# stock_return_cumulative(15)=SDDP.State{Float64}(1.0101327528681074, 1.1718708225588577)
#
#  ----------
#  ----------
# replication:2, stage:16
# wealth(16)=SDDP.State{Float64}(743.0147299885189, 728.4458137142342)
# invest(16)=0.0
# buy_order(16)=SDDP.State{Float64}(0.0, 1.0)
# sell_order(16)=SDDP.State{Float64}(1.0, 0.0)
# sell(16)=0.0
# stock_owned(16)=SDDP.State{Float64}(0.0, 0.0)
# cash(16)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(16)=1.0828567056280802
# stock_return_cumulative(16)=SDDP.State{Float64}(1.1718708225588577, 1.268968178337753)
#
#  ----------
#  ----------
# replication:2, stage:17
# wealth(17)=SDDP.State{Float64}(728.4458137142342, 833.8736865648336)
# invest(17)=1000.0
# buy_order(17)=SDDP.State{Float64}(1.0, 0.0)
# sell_order(17)=SDDP.State{Float64}(0.0, 0.0)
# sell(17)=0.0
# stock_owned(17)=SDDP.State{Float64}(0.0, 833.8736865648336)
# cash(17)=SDDP.State{Float64}(1000.0, 0.0)
# stock_return(17)=0.8422124234304821
# stock_return_cumulative(17)=SDDP.State{Float64}(1.268968178337753, 1.0687407647340033)
#
#  ----------
#  ----------
# replication:2, stage:18
# wealth(18)=SDDP.State{Float64}(833.8736865648336, 996.5562459833229)
# invest(18)=0.0
# buy_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell(18)=0.0
# stock_owned(18)=SDDP.State{Float64}(833.8736865648336, 996.5562459833229)
# cash(18)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(18)=1.195092568622311
# stock_return_cumulative(18)=SDDP.State{Float64}(1.0687407647340033, 1.277244145717333)
#
#  ----------
#  ----------
# replication:2, stage:19
# wealth(19)=SDDP.State{Float64}(996.5562459833229, 1202.8277727260631)
# invest(19)=0.0
# buy_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell(19)=0.0
# stock_owned(19)=SDDP.State{Float64}(996.5562459833229, 1202.8277727260631)
# cash(19)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(19)=1.206984329860085
# stock_return_cumulative(19)=SDDP.State{Float64}(1.277244145717333, 1.541613669286352)
#
#  ----------
#  ----------
# replication:2, stage:20
# wealth(20)=SDDP.State{Float64}(1202.8277727260631, 1466.240343167793)
# invest(20)=0.0
# buy_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell(20)=0.0
# stock_owned(20)=SDDP.State{Float64}(1202.8277727260631, 1466.240343167793)
# cash(20)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(20)=1.2189944199947573
# stock_return_cumulative(20)=SDDP.State{Float64}(1.541613669286352, 1.8792184606477063)
#
#  ----------
#  ----------
# replication:3, stage:1
# wealth(1)=SDDP.State{Float64}(0.0, 980.3921568627451)
# invest(1)=0.0
# buy_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell(1)=0.0
# stock_owned(1)=SDDP.State{Float64}(0.0, 0.0)
# cash(1)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(1)=0.99498743710662
# stock_return_cumulative(1)=SDDP.State{Float64}(1.0, 0.99498743710662)
#
#  ----------
#  ----------
# replication:3, stage:2
# wealth(2)=SDDP.State{Float64}(980.3921568627451, 961.1687812379854)
# invest(2)=0.0
# buy_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell(2)=0.0
# stock_owned(2)=SDDP.State{Float64}(0.0, 0.0)
# cash(2)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(2)=0.98
# stock_return_cumulative(2)=SDDP.State{Float64}(0.99498743710662, 0.9750876883644876)
#
#  ----------
#  ----------
# replication:3, stage:3
# wealth(3)=SDDP.State{Float64}(961.1687812379854, 942.3223345470446)
# invest(3)=0.0
# buy_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell(3)=0.0
# stock_owned(3)=SDDP.State{Float64}(0.0, 0.0)
# cash(3)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(3)=1.030149503712932
# stock_return_cumulative(3)=SDDP.State{Float64}(0.9750876883644876, 1.004486098245267)
#
#  ----------
#  ----------
# replication:3, stage:4
# wealth(4)=SDDP.State{Float64}(942.3223345470446, 923.8454260265142)
# invest(4)=0.0
# buy_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell(4)=0.0
# stock_owned(4)=SDDP.State{Float64}(0.0, 0.0)
# cash(4)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(4)=1.0201
# stock_return_cumulative(4)=SDDP.State{Float64}(1.004486098245267, 1.0246762688199968)
#
#  ----------
#  ----------
# replication:3, stage:5
# wealth(5)=SDDP.State{Float64}(923.8454260265142, 905.730809829916)
# invest(5)=0.0
# buy_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(5)=SDDP.State{Float64}(0.0, 1.0)
# sell(5)=0.0
# stock_owned(5)=SDDP.State{Float64}(0.0, 0.0)
# cash(5)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(5)=1.0
# stock_return_cumulative(5)=SDDP.State{Float64}(1.0246762688199968, 1.0246762688199968)
#
#  ----------
#  ----------
# replication:3, stage:6
# wealth(6)=SDDP.State{Float64}(905.730809829916, 887.9713821861919)
# invest(6)=0.0
# buy_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(6)=SDDP.State{Float64}(1.0, 0.0)
# sell(6)=0.0
# stock_owned(6)=SDDP.State{Float64}(0.0, 0.0)
# cash(6)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(6)=0.9411919999999999
# stock_return_cumulative(6)=SDDP.State{Float64}(1.0246762688199968, 0.9644171068032303)
#
#  ----------
#  ----------
# replication:3, stage:7
# wealth(7)=SDDP.State{Float64}(887.9713821861919, 870.5601786139138)
# invest(7)=0.0
# buy_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell(7)=0.0
# stock_owned(7)=SDDP.State{Float64}(0.0, 0.0)
# cash(7)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(7)=1.0717675436629344
# stock_return_cumulative(7)=SDDP.State{Float64}(0.9644171068032303, 1.0336309536250121)
#
#  ----------
#  ----------
# replication:3, stage:8
# wealth(8)=SDDP.State{Float64}(870.5601786139138, 853.4903711901114)
# invest(8)=0.0
# buy_order(8)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(8)=SDDP.State{Float64}(0.0, 1.0)
# sell(8)=0.0
# stock_owned(8)=SDDP.State{Float64}(0.0, 0.0)
# cash(8)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(8)=1.0
# stock_return_cumulative(8)=SDDP.State{Float64}(1.0336309536250121, 1.0336309536250121)
#
#  ----------
#  ----------
# replication:3, stage:9
# wealth(9)=SDDP.State{Float64}(853.4903711901114, 836.7552658726582)
# invest(9)=0.0
# buy_order(9)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(9)=SDDP.State{Float64}(1.0, 1.0)
# sell(9)=0.0
# stock_owned(9)=SDDP.State{Float64}(0.0, 0.0)
# cash(9)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(9)=1.045794087133964
# stock_return_cumulative(9)=SDDP.State{Float64}(1.0336309536250121, 1.0809651395796782)
#
#  ----------
#  ----------
# replication:3, stage:10
# wealth(10)=SDDP.State{Float64}(836.7552658726582, 820.3482998751551)
# invest(10)=0.0
# buy_order(10)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(10)=SDDP.State{Float64}(1.0, 1.0)
# sell(10)=0.0
# stock_owned(10)=SDDP.State{Float64}(0.0, 0.0)
# cash(10)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(10)=0.9039207967999999
# stock_return_cumulative(10)=SDDP.State{Float64}(1.0809651395796782, 0.9771068702818859)
#
#  ----------
#  ----------
# replication:3, stage:11
# wealth(11)=SDDP.State{Float64}(820.3482998751551, 804.2630390932893)
# invest(11)=0.0
# buy_order(11)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(11)=SDDP.State{Float64}(1.0, 1.0)
# sell(11)=0.0
# stock_owned(11)=SDDP.State{Float64}(0.0, 0.0)
# cash(11)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(11)=0.9462231524638975
# stock_return_cumulative(11)=SDDP.State{Float64}(0.9771068702818859, 0.9245611430922587)
#
#  ----------
#  ----------
# replication:3, stage:12
# wealth(12)=SDDP.State{Float64}(804.2630390932893, 788.4931755816563)
# invest(12)=0.0
# buy_order(12)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(12)=SDDP.State{Float64}(1.0, 1.0)
# sell(12)=0.0
# stock_owned(12)=SDDP.State{Float64}(0.0, 0.0)
# cash(12)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(12)=1.0
# stock_return_cumulative(12)=SDDP.State{Float64}(0.9245611430922587, 0.9245611430922587)
#
#  ----------
#  ----------
# replication:3, stage:13
# wealth(13)=SDDP.State{Float64}(788.4931755816563, 773.032525080055)
# invest(13)=0.0
# buy_order(13)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(13)=SDDP.State{Float64}(1.0, 1.0)
# sell(13)=0.0
# stock_owned(13)=SDDP.State{Float64}(0.0, 0.0)
# cash(13)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(13)=1.0
# stock_return_cumulative(13)=SDDP.State{Float64}(0.9245611430922587, 0.9245611430922587)
#
#  ----------
#  ----------
# replication:3, stage:14
# wealth(14)=SDDP.State{Float64}(773.032525080055, 757.8750245882894)
# invest(14)=0.0
# buy_order(14)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(14)=SDDP.State{Float64}(1.0, 1.0)
# sell(14)=0.0
# stock_owned(14)=SDDP.State{Float64}(0.0, 0.0)
# cash(14)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(14)=1.07213535210701
# stock_return_cumulative(14)=SDDP.State{Float64}(0.9245611430922587, 0.9912546866936784)
#
#  ----------
#  ----------
# replication:3, stage:15
# wealth(15)=SDDP.State{Float64}(757.8750245882894, 743.0147299885189)
# invest(15)=0.0
# buy_order(15)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(15)=SDDP.State{Float64}(1.0, 1.0)
# sell(15)=0.0
# stock_owned(15)=SDDP.State{Float64}(0.0, 0.0)
# cash(15)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(15)=1.0
# stock_return_cumulative(15)=SDDP.State{Float64}(0.9912546866936784, 0.9912546866936784)
#
#  ----------
#  ----------
# replication:3, stage:16
# wealth(16)=SDDP.State{Float64}(743.0147299885189, 728.4458137142342)
# invest(16)=0.0
# buy_order(16)=SDDP.State{Float64}(0.0, 1.0)
# sell_order(16)=SDDP.State{Float64}(1.0, 0.0)
# sell(16)=0.0
# stock_owned(16)=SDDP.State{Float64}(0.0, 0.0)
# cash(16)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(16)=1.1716593810022657
# stock_return_cumulative(16)=SDDP.State{Float64}(0.9912546866936784, 1.1614128526271101)
#
#  ----------
#  ----------
# replication:3, stage:17
# wealth(17)=SDDP.State{Float64}(728.4458137142342, 990.09900990099)
# invest(17)=1000.0
# buy_order(17)=SDDP.State{Float64}(1.0, 0.0)
# sell_order(17)=SDDP.State{Float64}(0.0, 0.0)
# sell(17)=0.0
# stock_owned(17)=SDDP.State{Float64}(0.0, 990.09900990099)
# cash(17)=SDDP.State{Float64}(1000.0, 0.0)
# stock_return(17)=1.0
# stock_return_cumulative(17)=SDDP.State{Float64}(1.1614128526271101, 1.1614128526271101)
#
#  ----------
#  ----------
# replication:3, stage:18
# wealth(18)=SDDP.State{Float64}(990.09900990099, 1082.85670562808)
# invest(18)=0.0
# buy_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell(18)=0.0
# stock_owned(18)=SDDP.State{Float64}(990.09900990099, 1082.85670562808)
# cash(18)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(18)=1.0936852726843609
# stock_return_cumulative(18)=SDDP.State{Float64}(1.1614128526271101, 1.2702201324246023)
#
#  ----------
#  ----------
# replication:3, stage:19
# wealth(19)=SDDP.State{Float64}(1082.85670562808, 1190.2112232840304)
# invest(19)=0.0
# buy_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell(19)=0.0
# stock_owned(19)=SDDP.State{Float64}(1082.85670562808, 1190.2112232840304)
# cash(19)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(19)=1.0991400959129514
# stock_return_cumulative(19)=SDDP.State{Float64}(1.2702201324246023, 1.3961498781837391)
#
#  ----------
#  ----------
# replication:3, stage:20
# wealth(20)=SDDP.State{Float64}(1190.2112232840304, 1450.8608397983674)
# invest(20)=0.0
# buy_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell(20)=0.0
# stock_owned(20)=SDDP.State{Float64}(1190.2112232840304, 1450.8608397983674)
# cash(20)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(20)=1.2189944199947573
# stock_return_cumulative(20)=SDDP.State{Float64}(1.3961498781837391, 1.7018989109823381)
#
#  ----------
#  ----------
# replication:4, stage:1
# wealth(1)=SDDP.State{Float64}(0.0, 980.3921568627451)
# invest(1)=0.0
# buy_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(1)=SDDP.State{Float64}(0.0, 0.0)
# sell(1)=0.0
# stock_owned(1)=SDDP.State{Float64}(0.0, 0.0)
# cash(1)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(1)=0.99498743710662
# stock_return_cumulative(1)=SDDP.State{Float64}(1.0, 0.99498743710662)
#
#  ----------
#  ----------
# replication:4, stage:2
# wealth(2)=SDDP.State{Float64}(980.3921568627451, 961.1687812379854)
# invest(2)=0.0
# buy_order(2)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(2)=SDDP.State{Float64}(0.0, 1.0)
# sell(2)=0.0
# stock_owned(2)=SDDP.State{Float64}(0.0, 0.0)
# cash(2)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(2)=1.0
# stock_return_cumulative(2)=SDDP.State{Float64}(0.99498743710662, 0.99498743710662)
#
#  ----------
#  ----------
# replication:4, stage:3
# wealth(3)=SDDP.State{Float64}(961.1687812379854, 942.3223345470446)
# invest(3)=0.0
# buy_order(3)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(3)=SDDP.State{Float64}(1.0, 0.0)
# sell(3)=0.0
# stock_owned(3)=SDDP.State{Float64}(0.0, 0.0)
# cash(3)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(3)=1.0150374377332099
# stock_return_cumulative(3)=SDDP.State{Float64}(0.99498743710662, 1.009949498737437)
#
#  ----------
#  ----------
# replication:4, stage:4
# wealth(4)=SDDP.State{Float64}(942.3223345470446, 923.8454260265142)
# invest(4)=0.0
# buy_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(4)=SDDP.State{Float64}(0.0, 0.0)
# sell(4)=0.0
# stock_owned(4)=SDDP.State{Float64}(0.0, 0.0)
# cash(4)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(4)=0.9801
# stock_return_cumulative(4)=SDDP.State{Float64}(1.009949498737437, 0.9898515037125619)
#
#  ----------
#  ----------
# replication:4, stage:5
# wealth(5)=SDDP.State{Float64}(923.8454260265142, 905.730809829916)
# invest(5)=0.0
# buy_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(5)=SDDP.State{Float64}(0.0, 0.0)
# sell(5)=0.0
# stock_owned(5)=SDDP.State{Float64}(0.0, 0.0)
# cash(5)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(5)=1.0507524937871906
# stock_return_cumulative(5)=SDDP.State{Float64}(0.9898515037125619, 1.040088936004975)
#
#  ----------
#  ----------
# replication:4, stage:6
# wealth(6)=SDDP.State{Float64}(905.730809829916, 887.9713821861919)
# invest(6)=0.0
# buy_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(6)=SDDP.State{Float64}(0.0, 0.0)
# sell(6)=0.0
# stock_owned(6)=SDDP.State{Float64}(0.0, 0.0)
# cash(6)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(6)=1.0
# stock_return_cumulative(6)=SDDP.State{Float64}(1.040088936004975, 1.040088936004975)
#
#  ----------
#  ----------
# replication:4, stage:7
# wealth(7)=SDDP.State{Float64}(887.9713821861919, 870.5601786139138)
# invest(7)=0.0
# buy_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(7)=SDDP.State{Float64}(0.0, 0.0)
# sell(7)=0.0
# stock_owned(7)=SDDP.State{Float64}(0.0, 0.0)
# cash(7)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(7)=0.9317325438379406
# stock_return_cumulative(7)=SDDP.State{Float64}(1.040088936004975, 0.9690847101616124)
#
#  ----------
#  ----------
# replication:4, stage:8
# wealth(8)=SDDP.State{Float64}(870.5601786139138, 853.4903711901114)
# invest(8)=0.0
# buy_order(8)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(8)=SDDP.State{Float64}(0.0, 1.0)
# sell(8)=0.0
# stock_owned(8)=SDDP.State{Float64}(0.0, 0.0)
# cash(8)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(8)=1.08243216
# stock_return_cumulative(8)=SDDP.State{Float64}(0.9690847101616124, 1.048968456043208)
#
#  ----------
#  ----------
# replication:4, stage:9
# wealth(9)=SDDP.State{Float64}(853.4903711901114, 836.7552658726582)
# invest(9)=0.0
# buy_order(9)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(9)=SDDP.State{Float64}(1.0, 1.0)
# sell(9)=0.0
# stock_owned(9)=SDDP.State{Float64}(0.0, 0.0)
# cash(9)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(9)=0.9130978929611817
# stock_return_cumulative(9)=SDDP.State{Float64}(1.048968456043208, 0.9578108869957972)
#
#  ----------
#  ----------
# replication:4, stage:10
# wealth(10)=SDDP.State{Float64}(836.7552658726582, 820.3482998751551)
# invest(10)=0.0
# buy_order(10)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(10)=SDDP.State{Float64}(1.0, 1.0)
# sell(10)=0.0
# stock_owned(10)=SDDP.State{Float64}(0.0, 0.0)
# cash(10)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(10)=0.9509900498999999
# stock_return_cumulative(10)=SDDP.State{Float64}(0.9578108869957972, 0.9108686232188964)
#
#  ----------
#  ----------
# replication:4, stage:11
# wealth(11)=SDDP.State{Float64}(820.3482998751551, 804.2630390932893)
# invest(11)=0.0
# buy_order(11)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(11)=SDDP.State{Float64}(1.0, 1.0)
# sell(11)=0.0
# stock_owned(11)=SDDP.State{Float64}(0.0, 0.0)
# cash(11)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(11)=0.8948359351019581
# stock_return_cumulative(11)=SDDP.State{Float64}(0.9108686232188964, 0.8150779762131143)
#
#  ----------
#  ----------
# replication:4, stage:12
# wealth(12)=SDDP.State{Float64}(804.2630390932893, 788.4931755816563)
# invest(12)=0.0
# buy_order(12)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(12)=SDDP.State{Float64}(1.0, 1.0)
# sell(12)=0.0
# stock_owned(12)=SDDP.State{Float64}(0.0, 0.0)
# cash(12)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(12)=1.0615201506010001
# stock_return_cumulative(12)=SDDP.State{Float64}(0.8150779762131143, 0.8652216960613035)
#
#  ----------
#  ----------
# replication:4, stage:13
# wealth(13)=SDDP.State{Float64}(788.4931755816563, 773.032525080055)
# invest(13)=0.0
# buy_order(13)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(13)=SDDP.State{Float64}(1.0, 1.0)
# sell(13)=0.0
# stock_owned(13)=SDDP.State{Float64}(0.0, 0.0)
# cash(13)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(13)=0.8769392163999189
# stock_return_cumulative(13)=SDDP.State{Float64}(0.8652216960613035, 0.7587468361562083)
#
#  ----------
#  ----------
# replication:4, stage:14
# wealth(14)=SDDP.State{Float64}(773.032525080055, 757.8750245882894)
# invest(14)=0.0
# buy_order(14)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(14)=SDDP.State{Float64}(1.0, 1.0)
# sell(14)=0.0
# stock_owned(14)=SDDP.State{Float64}(0.0, 0.0)
# cash(14)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(14)=1.0
# stock_return_cumulative(14)=SDDP.State{Float64}(0.7587468361562083, 0.7587468361562083)
#
#  ----------
#  ----------
# replication:4, stage:15
# wealth(15)=SDDP.State{Float64}(757.8750245882894, 743.0147299885189)
# invest(15)=0.0
# buy_order(15)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(15)=SDDP.State{Float64}(1.0, 1.0)
# sell(15)=0.0
# stock_owned(15)=SDDP.State{Float64}(0.0, 0.0)
# cash(15)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(15)=0.9273933117298659
# stock_return_cumulative(15)=SDDP.State{Float64}(0.7587468361562083, 0.703656741147464)
#
#  ----------
#  ----------
# replication:4, stage:16
# wealth(16)=SDDP.State{Float64}(743.0147299885189, 728.4458137142342)
# invest(16)=0.0
# buy_order(16)=SDDP.State{Float64}(0.0, 1.0)
# sell_order(16)=SDDP.State{Float64}(1.0, 0.0)
# sell(16)=0.0
# stock_owned(16)=SDDP.State{Float64}(0.0, 0.0)
# cash(16)=SDDP.State{Float64}(1000.0, 1000.0)
# stock_return(16)=0.8507630225817855
# stock_return_cumulative(16)=SDDP.State{Float64}(0.703656741147464, 0.5986451359586655)
#
#  ----------
#  ----------
# replication:4, stage:17
# wealth(17)=SDDP.State{Float64}(728.4458137142342, 1077.4826937682103)
# invest(17)=1000.0
# buy_order(17)=SDDP.State{Float64}(1.0, 0.0)
# sell_order(17)=SDDP.State{Float64}(0.0, 0.0)
# sell(17)=0.0
# stock_owned(17)=SDDP.State{Float64}(0.0, 1077.4826937682103)
# cash(17)=SDDP.State{Float64}(1000.0, 0.0)
# stock_return(17)=1.0882575207058924
# stock_return_cumulative(17)=SDDP.State{Float64}(0.5986451359586655, 0.6514800714410193)
#
#  ----------
#  ----------
# replication:4, stage:18
# wealth(18)=SDDP.State{Float64}(1077.4826937682103, 898.3487846632108)
# invest(18)=0.0
# buy_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(18)=SDDP.State{Float64}(0.0, 0.0)
# sell(18)=0.0
# stock_owned(18)=SDDP.State{Float64}(1077.4826937682103, 898.3487846632108)
# cash(18)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(18)=0.8337477621301498
# stock_return_cumulative(18)=SDDP.State{Float64}(0.6514800714410193, 0.5431700516363399)
#
#  ----------
#  ----------
# replication:4, stage:19
# wealth(19)=SDDP.State{Float64}(898.3487846632108, 987.4111693380049)
# invest(19)=0.0
# buy_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(19)=SDDP.State{Float64}(0.0, 0.0)
# sell(19)=0.0
# stock_owned(19)=SDDP.State{Float64}(898.3487846632108, 987.4111693380049)
# cash(19)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(19)=1.0991400959129514
# stock_return_cumulative(19)=SDDP.State{Float64}(0.5431700516363399, 0.5970199826526094)
#
#  ----------
#  ----------
# replication:4, stage:20
# wealth(20)=SDDP.State{Float64}(987.4111693380049, 1203.6487056635265)
# invest(20)=0.0
# buy_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell_order(20)=SDDP.State{Float64}(0.0, 0.0)
# sell(20)=0.0
# stock_owned(20)=SDDP.State{Float64}(987.4111693380049, 1203.6487056635265)
# cash(20)=SDDP.State{Float64}(0.0, 0.0)
# stock_return(20)=1.2189944199947573
# stock_return_cumulative(20)=SDDP.State{Float64}(0.5970199826526094, 0.7277640274788977)
#
#  ----------
#  ----------

# %%
init_v_int = 1:(REPLICATIONS * STAGES)
init_v = -1.0 * init_v_int
# stands, replications, stages

df = DataFrame(
    replication = init_v_int,
    stage = init_v_int,
    wealth_in = init_v,
    wealth_out = init_v,
    cash_in = init_v,
    cash_out = init_v,
    stock_owned_in = init_v,
    stock_owned_out = init_v,
    invest = init_v,
    sell = init_v,
    stock_return = init_v,
    stock_return_cumulative_in = init_v,
    stock_return_cumulative_out = init_v
)

#df[:, "total_stages"] .= stages

df[:, "buy_order_in"] .= 0.0
df[:, "buy_order_out"] .= 0.0
df[:, "sell_order_in"] .= 0
df[:, "sell_order_out"] .= 0

row = 1
for replication in 1:REPLICATIONS
    for stage in 1:STAGES
        for item in mylist
            
            df[row, :replication] = replication
            df[row, :stage] = stage
            
            if item == :wealth
                df[row, :wealth_in] = simulations[replication][stage][item].in
                df[row, :wealth_out] = simulations[replication][stage][item].out
            elseif item == :cash
                df[row, :cash_in] = simulations[replication][stage][item].in
                df[row, :cash_out] = simulations[replication][stage][item].out
            elseif item == :stock_owned
                df[row, :stock_owned_in] = simulations[replication][stage][item].in
                df[row, :stock_owned_out] = simulations[replication][stage][item].out
            elseif item == :buy_order
                df[row, :buy_order_in] = simulations[replication][stage][item].in
                df[row, :buy_order_out] = simulations[replication][stage][item].out
            elseif item == :sell_order
                df[row, :sell_order_in] = simulations[replication][stage][item].in
                df[row, :sell_order_out] = simulations[replication][stage][item].out
            elseif item == :stock_return_cumulative
                df[row, :stock_return_cumulative_in] = simulations[replication][stage][item].in
                df[row, :stock_return_cumulative_out] = simulations[replication][stage][item].out
            else
                df[row, item] = simulations[replication][stage][item]
                #[item][stand]
            end

        end
        row = row + 1

    end
end

CSV.write("optimization_model_results/results.csv", df)
# Out:
# "optimization_model_results/results.csv"

# %%
2-1.04
# Out:
# 0.96

# %%
"""
transition_matrix = [STATE_1_PR 1-STATE_1_PR; STATE_1_PR 1-STATE_1_PR]

transition_matrix_vector =
Vector{Matrix{Float64}}(
    vcat(
        [[1.0]', [STATE_1_PR 1-STATE_1_PR]] , 
    [transition_matrix for i in 1:stages] 
        ))
"""
# Out:
# "transition_matrix = [STATE_1_PR 1-STATE_1_PR; STATE_1_PR 1-STATE_1_PR]\n\ntransition_matrix_vector =\nVector{Matrix{Float64}}(\n    vcat(\n        [[1.0]', [STATE_1_PR 1-STATE_1_PR]] , \n    [transition_matrix for i in 1:stages] \n        ))\n"

# %%
init_v_int = 1:(REPLICATIONS * STAGES)
init_v = -1.0 * init_v_int
# stands, replications, stages

df = DataFrame(
    replication = init_v_int,
    stage = init_v_int,
    wealth_in = init_v,
    wealth_out = init_v,
    cash_in = init_v,
    cash_out = init_v,
    stock_owned_in = init_v,
    stock_owned_out = init_v,
    invest = init_v,
    sell = init_v,
    stock_return = init_v,
    stock_return_cumulative_in = init_v,
    stock_return_cumulative_out = init_v
)

#df[:, "total_stages"] .= stages

row = 1
for replication in 1:REPLICATIONS
    for stage in 1:STAGES
        for item in mylist
            
            df[row, :replication] = replication
            df[row, :stage] = stage
            
            if item == :wealth
                df[row, :wealth_in] = simulations[replication][stage][item].in
                df[row, :wealth_out] = simulations[replication][stage][item].out
            elseif item == :cash
                df[row, :cash_in] = simulations[replication][stage][item].in
                df[row, :cash_out] = simulations[replication][stage][item].out
            elseif item == :stock_owned
                df[row, :stock_owned_in] = simulations[replication][stage][item].in
                df[row, :stock_owned_out] = simulations[replication][stage][item].out
            elseif item == :stock_return_cumulative
                df[row, :stock_return_cumulative_in] = simulations[replication][stage][item].in
                df[row, :stock_return_cumulative_out] = simulations[replication][stage][item].out
            else
                df[row, item] = simulations[replication][stage][item]
                #[item][stand]
            end

        end
        row = row + 1

    end
end

CSV.write("optimization_model_results/results.csv", df)
# Out:
# "optimization_model_results/results.csv"

# %%
df
# Out:
# 20×13 DataFrame
#  Row │ replication  stage  wealth_in  wealth_out  cash_in  cash_out  stock_own ⋯
#      │ Int64        Int64  Float64    Float64     Float64  Float64   Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │           1      1    1000.0      1000.0   1000.0    1000.0             ⋯
#    2 │           1      2    1000.0      1010.73  1000.0       0.0
#    3 │           1      3    1010.73     1000.62     0.0    1000.62         10
#    4 │           1      4    1000.62     1031.99  1000.62      0.0
#    5 │           1      5    1031.99     1021.67     0.0    1021.67         10 ⋯
#    6 │           2      1    1000.0      1006.6   1000.0       0.0
#    7 │           2      2    1006.6      1006.6      0.0       0.0          10
#    8 │           2      3    1006.6      1034.56     0.0       0.0          10
#    9 │           2      4    1034.56     1024.22     0.0    1024.22         10 ⋯
#   10 │           2      5    1024.22     1024.22  1024.22   1024.22
#   11 │           3      1    1000.0      1023.1   1000.0       0.0
#   12 │           3      2    1023.1      1012.87     0.0    1012.87         10
#   13 │           3      3    1012.87     1086.41  1012.87      0.0             ⋯
#   14 │           3      4    1086.41     1176.95     0.0       0.0          10
#   15 │           3      5    1176.95     1373.11     0.0       0.0          11
#   16 │           4      1    1000.0      1000.0   1000.0    1000.0
#   17 │           4      2    1000.0      1000.0   1000.0    1000.0             ⋯
#   18 │           4      3    1000.0      1000.0   1000.0    1000.0
#   19 │           4      4    1000.0      1072.61  1000.0       0.0
#   20 │           4      5    1072.61     1061.88     0.0    1061.88         10
#                                                                7 columns omitted

# %%
[ [s; s3] for s in [[s1, s2] for s1 in stock_projections for s2 in stock_projections] for s3 in stock_projections][35][3]
# Out:
# 1.25

# %%
[[s1,s2,s3] for s1 in stock_projections for s2 in stock_projections for s3 in stock_projections][35][3]
# Out:
# 1.25

# %%
stock_projection_list = [stock_projections, stock_projections]

answ = []
for stock_projection in stock_projection_list
    
    if length(answ) == 0
        answ = [[s] for s in stock_projection]
    else
        answ = [[s; s_new] for s in answ for s_new in stock_projection] 
    end
    
end

# %%
function create_joint_probability_distribution(stock_projection_list)  
    answ = []
    
    for stock_projection in stock_projection_list
        if length(answ) == 0
            answ = [[s] for s in stock_projection]
        else
            answ = [[s; s_new] for s in answ for s_new in stock_projection]
        end
    end
        
    answ
end
# Out:
# create_joint_probability_distribution (generic function with 1 method)

# %%
create_joint_probability_distribution([stock_projections,stock_projections .* 1.01])
# Out:
# 1225-element Vector{Vector{Float64}}:
#  [0.95, 0.9594999999999999]
#  [0.95, 0.946875]
#  [0.95, 0.9258333333333333]
#  [0.95, 0.88375]
#  [0.95, 0.7575000000000001]
#  [0.95, 0.9763333333333334]
#  [0.95, 0.9679166666666668]
#  [0.95, 0.9538888888888889]
#  [0.95, 0.9258333333333333]
#  [0.95, 0.8416666666666667]
#  [0.95, 0.9931666666666666]
#  [0.95, 0.9889583333333333]
#  [0.95, 0.9819444444444444]
#  ⋮
#  [1.25, 1.0520833333333335]
#  [1.25, 1.0941666666666665]
#  [1.25, 1.0436666666666667]
#  [1.25, 1.0520833333333335]
#  [1.25, 1.0661111111111112]
#  [1.25, 1.0941666666666665]
#  [1.25, 1.1783333333333335]
#  [1.25, 1.0605]
#  [1.25, 1.073125]
#  [1.25, 1.0941666666666665]
#  [1.25, 1.13625]
#  [1.25, 1.2625]

# %%
[[s;s_new] for s in [1] for s_new in stock_projections]
# Out:
# 35-element Vector{Vector{Float64}}:
#  [1.0, 0.95]
#  [1.0, 0.9375]
#  [1.0, 0.9166666666666666]
#  [1.0, 0.875]
#  [1.0, 0.75]
#  [1.0, 0.9666666666666667]
#  [1.0, 0.9583333333333334]
#  [1.0, 0.9444444444444444]
#  [1.0, 0.9166666666666666]
#  [1.0, 0.8333333333333334]
#  [1.0, 0.9833333333333333]
#  [1.0, 0.9791666666666666]
#  [1.0, 0.9722222222222222]
#  ⋮
#  [1.0, 1.0416666666666667]
#  [1.0, 1.0833333333333333]
#  [1.0, 1.0333333333333334]
#  [1.0, 1.0416666666666667]
#  [1.0, 1.0555555555555556]
#  [1.0, 1.0833333333333333]
#  [1.0, 1.1666666666666667]
#  [1.0, 1.05]
#  [1.0, 1.0625]
#  [1.0, 1.0833333333333333]
#  [1.0, 1.125]
#  [1.0, 1.25]
